# %% [markdown]
# #### Notebook 4: This is a preliminary EDA notebook for project proposal revision

# %%
# Import Libraries
import os
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Data

path = "C:\\Users\\juhic\\OneDrive\\Desktop\\master_dataset.csv"
data = pd.read_csv(path)
data.drop(axis = 1, columns = 'Unnamed: 0', inplace = True)

# %%
data.head()
# Out:
#                                                title           series  \
# 0                                       inner circle         private
# 1                                  a time to embrace   timeless love
# 2                                           take two  above the line
# 3                                          reliquary      pendergast
# 4  the millionaire next door: the surprising secr...              NaN
#
#               author  rating_count  review_count  average_rating  \
# 0         kate brian          7597           196            4.03
# 1    karen kingsbury          4179           177            4.35
# 2    karen kingsbury          6288           218            4.23
# 3    douglas preston         38382          1424            4.01
# 4  thomas j. stanley         72168          3217            4.04
#
#    five_star_ratings  four_star_ratings  three_star_ratings  two_star_ratings  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54408 entries, 0 to 54407
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                54408 non-null  object
#  1   series               24436 non-null  object
#  2   author               54408 non-null  object
#  3   rating_count         54408 non-null  int64
#  4   review_count         54408 non-null  int64
#  5   average_rating       54408 non-null  float64
#  6   five_star_ratings    54408 non-null  int64
#  7   four_star_ratings    54408 non-null  int64
#  8   three_star_ratings   54408 non-null  int64
#  9   two_star_ratings     54408 non-null  int64
#  10  one_star_ratings     54408 non-null  int64
#  11  page_count           54408 non-null  int64
#  12  published_year       53385 non-null  float64
#  13  publisher            50690 non-null  object
#  14  genre                51532 non-null  object
# ...

# %%
# Hypothesis 1: Male & Female

fig, ax = plt.subplots(figsize = (10,5))
sns.countplot(data = data, x = 'gender')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
# Hypothesis 2: Published Year

d = data[data['published_year']>1960]
fig, ax = plt.subplots(figsize = (50,10))
sns.countplot(data = d, x = 'published_year')
# Out:
# <AxesSubplot:xlabel='published_year', ylabel='count'>

# %%
# Hypothesis 3: Country

fig, ax = plt.subplots(figsize = (10,4))
top_countries = sns.barplot(x = data['author_country'].value_counts()[0:8].index,
y = data['author_country'].value_counts()[0:8])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54408 entries, 0 to 54407
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                54408 non-null  object
#  1   series               24436 non-null  object
#  2   author               54408 non-null  object
#  3   rating_count         54408 non-null  int64
#  4   review_count         54408 non-null  int64
#  5   average_rating       54408 non-null  float64
#  6   five_star_ratings    54408 non-null  int64
#  7   four_star_ratings    54408 non-null  int64
#  8   three_star_ratings   54408 non-null  int64
#  9   two_star_ratings     54408 non-null  int64
#  10  one_star_ratings     54408 non-null  int64
#  11  page_count           54408 non-null  int64
#  12  published_year       53385 non-null  float64
#  13  publisher            50690 non-null  object
#  14  genre                51532 non-null  object
# ...

# %%
data.loc[data['title'].str.contains('harry potter'),['title','series','author','volume']]
#data[['title','series','volume']]
# Out:
#                                                    title  \
# 323    harry potter schoolbooks box set: two classic ...
# 1689   selections from harry potter and the order of ...
# 1690   selections from harry potter and the order of ...
# 1691   selections from harry potter and the order of ...
# 1692   selections from harry potter and the order of ...
# 1693   selections from harry potter and the order of ...
# 3145                    harry potter: a history of magic
# 7151                           harry potter: the prequel
# 13158           harry potter and the philosopher's stone
# 13159                  harry potter y el cã¡liz de fuego
# 18844           harry potter and the prisoner of azkaban
# 23756  harry potter: a pop-up book: based on the film...
# 24669  the unofficial harry potter cookbook: from cau...
# 26246           harry potter and the prisoner of azkaban
# 30775                           the end of harry potter?
# ...

# %%
# Hypothesis 4: Genre

fig, ax = plt.subplots(figsize = (18,4))
top_countries = sns.barplot(x = data['genre'].value_counts()[0:10].index,
y = data['genre'].value_counts()[0:10])
